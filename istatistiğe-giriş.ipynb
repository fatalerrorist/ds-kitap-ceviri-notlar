# %% [markdown]
# # **Python ile istatistiğe giriş**

# %% [markdown]
# Her gün belirsiz durumlarla karşı karşıya kalıyoruz ve eksik verilere dayanarak kararlar vermek zorunda kalıyoruz: “Otobüse yetişir miyim? Hangi hisse senedini almalıyım? Hangi adamla evlenmeliyim? Bu ilacı almalı mıyım? Çocuklarıma aşı yaptırmalı mıyım?” Bu sorulardan bazıları, çok fazla bilinmeyen değişken içerdikleri için istatistik alanının ötesindedir. ( örn. “Hangi kişiyle evlenmeliyim?”). Ancak birçok durumda, istatistikler verilen bilgilerden maksimum düzeyde bilgi çıkarmaya yardımcı olabilir ve bildiklerimizi ve bilmediklerimizi açıkça ortaya koyar. Örneğin, “Bu ilaç mide bulantısına neden olabilir” veya “Bu ilacı almazsan ölebilirsin” gibi belirsiz bir ifadeyi, “Bu ilacı kullanırken bin hastadan üçü mide bulantısı yaşıyor. ” veya “Bu ilacı almazsanız, ölme ihtimaliniz %95'tir.” şeklinde açıklayabiliriz. İstatistikler olmadan, verilerin yorumlanması hızla büyük ölçüde kusurlu hale gelebilir. Örneğin, "Alman Tank Problemi" olarak da bilinen 2. Dünya Savaşı sırasında üretilen tahmini Alman tankı sayısını ele alalım. Standart istihbarat verilerinden aylık üretilen Alman tankı sayısının tahmini 1550 idi; ancak, gözlemlenen tank sayısına dayalı istatistiksel tahmin 327 idi ve bu, 342 olan gerçek üretim sayısına çok yakındı (http://en.wikipedia.org/wiki/German_tank_problem).

# %% [markdown]
# Genel olarak istatistik bu konuları kapsar:
# - Soruyu netleştirmek
# - Soruyu cevaplayacak değişkeni ve değişkenin ölçüsünü belirlemek.
# - Gerekli örneklem büyüklüğünü belirlemek.
# - Değişkenliği tanımlamak.
# - Tahmini parametreler hakkında nicel ifadeler kullanmak.
# - Verilerinize dayanarak tahminlerde bulunmak.

# %% [markdown]
# ## **Nüfus ve Örneklem**

# %% [markdown]
# Verinin istatistiksel analizinde kullanılan verileri nüfusun içerisinden nüfusu temsil edecek şekilde alınan örneklerden sağlarız. Verinin doğru analizi bütün bir nüfustan sağlanamayacak kadar büyük ölçekli nüfusa sahip olduğumuzda, genel nüfusu doğru temsil edecek örneklem ile sağlanır.

# %% [markdown]
# #### <b>Nüfus</b>,
# bir veri kümesindeki tüm öğeleri içerirken,
#
# #### <b>Örneklem</b>
# ise nüfustan alınan bir veya daha fazla gözlemden oluşur.

# %% [markdown]
# - Örneklem, bir veri kümesinin tümünü temsil eder.
# - Örneklem, nüfusun(popülasyonun) bir alt kümesidir.
# - Örneklem, nüfus içerisinden birden fazla kez seçilebilir.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# İstatistiksel çıkarım söz konusu olduğunda, örneklem üzerinden alınan bilgi nüfus hakkında genellemeler yapılmasına olanak sağlar. Bu sebeple örneklem seçiminde nüfusu temsil edecek **parametrelerin** bilinmesi ve örneklem seçiminde bu **parametrelere** göre seçim yapılması önemlidir.

# %% [markdown]
# Avrupalı erkeklerin kilosunu incelememiz gereken senaryoda tüm avrupalıları ele alıp kilolarını ölçemeyiz. Bu durumda avrupalı erkeklerin kilosunu ölçmek için bir örneklem seçmemiz gerekir. Örneğin, 1000 avrupalı erkeğin kilosunu ölçebiliriz. Unutmamalıyız ki,  örneklem aynı zamanda nüfusun **parametrelerini**  aynı derecede temsil etmelidir. Örneğin, bölgelerin nüfus oranlarına göre örneklem seçmek gerekir. Örneğin, 1000 avrupalı erkeğin kilosunu ölçerken, 500'ü Almanya'dan, 250'si Fransa'dan, 250'si İtalya'dan olmalıdır. Bu şekilde örneklem seçmek, nüfusun her türlü **paremetresini** en yakın şekilde temsil edecektir.

# %% [markdown]
# ### **Parametre**,
#  popülasyonun(nüfus) ve örneklemin sayısal değerlerine verilen genel bir addır. Popülasyon ile örneklem arasındaki parametre benzerliği standart sapma ve normal dağılım ile ölçülebilir.

# %% [markdown]
# ### <b> İstatistik, </b>
#  bir örneklemdeki verileri kullanarak bir nüfus hakkında çıkarımlarda bulunmaktır. Örneğin, bir örneklemdeki verileri kullanarak bir nüfusun ortalama değerini tahmin edebiliriz. Aynı zamanda istatistik örnekleri şunlardır:
#
# - Örneklemin ortalaması
# - Örneklemin sapması
# - Örneklemin korelasyon katsayısı
# - Örneklemin regresyon eğrisi
# - Örneklemin dağılımı

# %% [markdown]
# ### **Örneklem Dağılımı**,
#  popülasyondan seçilen örneklemin parametrik özelliklerinin olasılık dağılımıdır. Örnek verirsek 100 insandan popülasyondan rastgele seçilen 10 kişinin kaç kilo olduklarının veya ne kadar uzunluğa sahip olduklarının olasılıksal dağılımı örneklem dağılımıdır.
#
# Bu 10 kişinin her birinin kilosu genel olarak ele alındığında bize örneklem dağılımını sunmuş olur.

# %% [markdown]
# ### **Peki ya Olasılıksal dağılım nedir?**
#
# Elimizde bir zar olduğunu düşünelim. Bu zarı 10 defa atıyoruz ve her gelen değeri not ediyoruz ve genel olarak bu değerlerin her birinin kaç defa geldiğini de yanına yazıyoruz. İşte bu değerlerin sıklığı bize olasılıksal dağılımı sunmuş olur. Örneğin 10 defa atılan zarda 5 değerinin 3 defa geldiğini düşünelim. Bu durumda 5 değerinin olasılıksal dağılımı 3/10 olur. Bu gibi dağılımları grafikte göstermek istediğimizde bu gibi bir grafik ortaya çıkar.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Değerler ve sayıları
values = [1, 2, 3, 4, 5, 6]
counts = [2, 1, 1, 1, 3, 2]  # Örnek veriler

# Grafik oluşturma
fig, ax = plt.subplots()
ax.plot(values, counts, linewidth=1, color='blue')
ax.fill_between(values, counts, color='blue', alpha=0.2, hatch='\\')

# 5 değerini vurgula
ax.plot([5, 5], [0, counts[4]], linewidth=1, color='green', linestyle='--')

# Grafik ayarları
fig.set_dpi(300)
plt.xticks(values)
plt.xlabel('Zar Değeri')
plt.ylabel('Yoğunluk')
plt.title('10 Defa Atılan Zarda 5 Değerinin Kaç Kez geldiği')

plt.show()

# %% [markdown]
# ### **İstatistiksel Çıkarım,**
# bir örneklemdeki verileri kullanarak bir nüfus hakkında çıkarımlarda bulunmaktır. Örneğin, bir örneklemdeki verileri kullanarak bir nüfusun ortalama değerini tahmin edebiliriz. İstatistiksel çıkarımlardan bazıları şunlardır:
#  - 10 kişinin medyan ortalama kilosu 78.5 kg'dır. Standart sapma ise 2.3 kg'dır. Bu duruma göre, bir sonraki kişinin kilosu 78.5 kg'dan 2.3 kg sapma ile 76.2 kg ile 80.8 kg arasında olması yüksek olasılıktır.
#
# - Bir örneklemdeki matematik sınav sonuçlarına dayanarak, bir öğrencinin bir sonraki sınavda alacağı notun ortalama sınav notundan 1 standart sapma düşük veya yüksek olması olasılığı hesaplanabilir.
#
# - Bir örneklemdeki çalışanların saatlik ücretlerine dayanarak, bir sonraki çalışanın ücretinin örneklem ortalamasından 2 standart sapma düşük veya yüksek olması olasılığı hesaplanabilir.
#
# - Bir örneklemdeki satış rakamlarına dayanarak, bir sonraki satışın örneklem ortalamasından 1.5 standart sapma düşük veya yüksek olması olasılığı hesaplanabilir.
#
#
# ![image.png](attachment:image.png)
#
# İstatistik üzerinde çalışırken örneklem dağılımının ortalama değerini '$\bar{x}$' şeklinde , popülasyon üzerinde çalışırken ise '$\mu$' şeklinde gösteririz.
#
# Aynı zamanda standart sapma için örneklem dağılımında '$sd$' ve popülasyon dağılımında '$\sigma$' şeklinde gösteririz.
